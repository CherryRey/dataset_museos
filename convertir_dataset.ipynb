# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import chain
# %matplotlib inline

# %%
df_museos = pd.read_csv("museos_raw.csv", sep=";", encoding = 'unicode_escape', engine ='python')
df_museos.head()
# Out:
#         PK                                             NOMBRE  \
# 0  4847190                            Casa Museo Lope de Vega
# 1  4949641                     Casita - Museo del Ratón Pérez
# 2  5682031                             Castillo de la Alameda
# 3     2064                             Casón del Buen Retiro.
# 4     2069  Centro Cultural La Corrala. Museo de Artes y T...
#
#                                  DESCRIPCION-ENTIDAD  \
# 0  'Mi casilla, mi quietud, mi g&amp;uuml;ertecil...
# 1  La Casita-Museo de Ratón Pérez, constituye un ...
# 2  El Castillo de la Alameda o de Barajas se trat...
# 3  El Centro de Estudios del Prado está ubicado e...
# 4                                                NaN
#
#                                              HORARIO  \
# 0  De martes a domingo, de 10 a 18 horas.  Cerrad...
# 1  Visitas:     Lunes: 11 a 14 horas.   Martes a ...
# 2  Abierto solo en fin de semana (sábado y doming...
# ...

# %%
#obtener el nombre de las columnas en una lista
column_name = df_museos.columns.tolist()
list_column = list(column_name)
list_column
# Out:
# ['PK',
#  'NOMBRE',
#  'DESCRIPCION-ENTIDAD',
#  'HORARIO',
#  'EQUIPAMIENTO',
#  'TRANSPORTE',
#  'DESCRIPCION',
#  'ACCESIBILIDAD',
#  'CONTENT-URL',
#  'NOMBRE-VIA',
#  'CLASE-VIAL',
#  'TIPO-NUM',
#  'NUM',
#  'PLANTA',
#  'PUERTA',
#  'ESCALERAS',
#  'ORIENTACION',
#  'LOCALIDAD',
#  'PROVINCIA',
#  'CODIGO-POSTAL',
#  'COD-BARRIO',
#  'BARRIO',
#  'COD-DISTRITO',
#  'DISTRITO',
#  'COORDENADA-X',
#  'COORDENADA-Y',
#  'LATITUD',
#  'LONGITUD',
#  'TELEFONO',
#  'FAX',
#  'EMAIL',
#  'TIPO',
#  'Unnamed: 32']

# %%
#Eliminar columnas que no ocupo

df_museos_drop = df_museos.drop([
    'PK', 
    'DESCRIPCION-ENTIDAD',
    'HORARIO', 
    'EQUIPAMIENTO', 
    'TRANSPORTE', 
    'DESCRIPCION', 
    'ACCESIBILIDAD',
    'CONTENT-URL',
    'NOMBRE-VIA',
    'CLASE-VIAL',
    'TIPO-NUM',
    'NUM',
    'PLANTA',
    'PUERTA',
    'ESCALERAS',
    'ORIENTACION',
    'PROVINCIA',
    'COD-BARRIO',
    'COD-DISTRITO',
    'COORDENADA-X',
    'COORDENADA-Y',
    'TELEFONO',
    'FAX',
    'EMAIL',
     'TIPO',
    'Unnamed: 32'], axis=1)

df_museos_drop
# Out:
#                                                NOMBRE LOCALIDAD  \
# 0                             Casa Museo Lope de Vega    MADRID
# 1                      Casita - Museo del Ratón Pérez    MADRID
# 2                              Castillo de la Alameda    MADRID
# 3                              Casón del Buen Retiro.    MADRID
# 4   Centro Cultural La Corrala. Museo de Artes y T...    MADRID
# ..                                                ...       ...
# 63            Real Monasterio de las Descalzas Reales    MADRID
# 64                                    Templo de Debod    MADRID
# 65                 The Robot Museum (Museo del Robot)    MADRID
# 66  Yacimiento paleontológico. Estación de Metro C...    MADRID
# 67                          Zapadores Ciudad del Arte    MADRID
#
#     CODIGO-POSTAL            BARRIO             DISTRITO    LATITUD  LONGITUD
# 0           28014            CORTES               CENTRO  40.414358 -3.697474
# ...

# %%
display (df_museos_drop.dtypes)
# Out:
# NOMBRE            object
# LOCALIDAD         object
# CODIGO-POSTAL      int64
# BARRIO            object
# DISTRITO          object
# LATITUD          float64
# LONGITUD         float64
# dtype: object

# %%
df_museos_drop.isnull().sum()
# Out:
# NOMBRE           0
# LOCALIDAD        0
# CODIGO-POSTAL    0
# BARRIO           0
# DISTRITO         0
# LATITUD          0
# LONGITUD         0
# dtype: int64

# %%
df_museos_drop.to_csv('nuevo_museos.csv')
